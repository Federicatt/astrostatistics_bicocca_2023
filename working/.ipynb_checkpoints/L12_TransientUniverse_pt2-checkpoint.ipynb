# %% [markdown]
# # The Transient Universe part 2

# %%
import numpy as np
from numpy import random as rnd
import emcee
import matplotlib.pyplot as plt
import scipy

import corner
import dynesty
from dynesty import plotting as dyplot
from dynesty import utils as dyfunc

plt.rcParams['figure.figsize'] = [8, 8]
plt.rcParams['font.size'] = 15

# %% [markdown]
# 7) Fit the same model from before with the same priors,  but this time use nested sampling.
#
# $y = b$, for $t<t_0$
#
# $y = b + A\exp[-\alpha(t-t_0)]$, for $t\geq t_0$
#
# Be careful with how you transform your parameter space into a unit hypercube for the nested sampling priors (I used `ppf` from `scipy.stats.uniform`, but there are other ways to do it)
#
# An appropriate check on whether you have done things correctly is that the posterior samples you get from the burst analysis here should give an equivalent corner plot to the MCMC you did earlier.

# %%
data = np.load("transient.npy")
#print(data)

t = data[:,0] #time
f = data[:,1] #flux
f_err = data[:,2] #flux error

plt.errorbar(t, f, yerr=f_err, fmt='o', color='b')
plt.xlabel('Time')
plt.ylabel('Flux')
plt.title('Data')
plt.show()

# %% [markdown]
# Model to use here:
#
# $y = b$, for $t<t_0$
#
# $y = b + A\exp[-\alpha(t-t_0)]$, for $t\geq t_0$

# %%
#burst model
def model(p, t):
    b, A, t_0, alpha = p
    return np.where(t < t_0, b, b+A*np.exp(-alpha*(t-t_0)))

# %% [markdown]
# We change the parameters space for nested sampling priors.  For the priors I make them
# $b=[0,50]$, $A=[0,50]$, $t_0=[0,100]$, and $\alpha=[-5,5]$.

# %% [markdown]
# ## Nested Sampling

# %%
#define the dimensionality of the problem
ndim = 4

#x are the samples
def priormodel(x): 
    b = x[0]*50
    A = x[1]*50
    t_0 = x[2]*100
    alpha = scipy.stats.loguniform.ppf(x[3], np.exp(-5), np.exp(5))
    
    param = np.array([b, A, t_0, alpha])
    return param


def loglike_model(param, t, f, f_err):
    b, A, t_0, alpha = param 
    model_brust = model(param, t)
    return (-0.5)* np.sum((f - model_brust)**2/(f_err**2))

# %%
#nested sampling

sampler = dynesty.NestedSampler(loglike_model, priormodel, ndim, logl_args=[t, f, f_err], nlive=1000)
sampler.run_nested()
sresults = sampler.results
# Out:
# /home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in exp
#   after removing the cwd from sys.path.
# /home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in multiply
#   after removing the cwd from sys.path.
# 3493it [00:12, 80.31it/s, bound: 0 | nc: 22 | ncall: 34882 | eff(%): 10.014 | loglstar:   -inf < -186.424 <    inf | logz: -194.931 +/-  0.087 | dlogz: 129.689 >  1.009]     /home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in exp
#   after removing the cwd from sys.path.
# 3502it [00:13, 29.33it/s, bound: 1 | nc: 11 | ncall: 34999 | eff(%): 10.006 | loglstar:   -inf < -185.398 <    inf | logz: -193.758 +/-  0.086 | dlogz: 128.495 >  1.009]/home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in multiply
#   after removing the cwd from sys.path.
# 3770it [00:15, 132.90it/s, bound: 1 | nc: 14 | ncall: 36422 | eff(%): 10.351 | loglstar:   -inf < -150.004 <    inf | logz: -158.099 +/-  0.085 | dlogz: 92.513 >  1.009] /home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in exp
#   after removing the cwd from sys.path.
# /home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in multiply
#   after removing the cwd from sys.path.
# 4054it [00:17, 133.96it/s, bound: 2 | nc: 10 | ncall: 37877 | eff(%): 10.703 | loglstar:   -inf < -124.825 <    inf | logz: -133.151 +/-  0.086 | dlogz: 67.273 >  1.009]/home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in exp
#   after removing the cwd from sys.path.
# /home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in multiply
#   after removing the cwd from sys.path.
# 4167it [00:19, 61.78it/s, bound: 3 | nc: 12 | ncall: 39430 | eff(%): 10.568 | loglstar:   -inf < -118.777 <    inf | logz: -126.956 +/-  0.085 | dlogz: 60.952 >  1.009] /home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in exp
#   after removing the cwd from sys.path.
#
>  1.009]/home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in exp
#   after removing the cwd from sys.path.
# /home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in multiply
#   after removing the cwd from sys.path.
# 8596it [03:39,  7.28it/s, bound: 86 | nc: 64 | ncall: 163902 | eff(%):  5.245 | loglstar:   -inf < -82.334 <    inf | logz: -92.314 +/-  0.086 | dlogz: 34.386 >  1.009] /home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in exp
#   after removing the cwd from sys.path.
# 8598it [03:40,  3.61it/s, bound: 87 | nc: 52 | ncall: 163995 | eff(%):  5.243 | loglstar:   -inf < -82.310 <    inf | logz: -92.306 +/-  0.087 | dlogz: 34.376 >  1.009]/home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in multiply
#   after removing the cwd from sys.path.
# 8645it [03:41, 24.08it/s, bound: 87 | nc: 110 | ncall: 165404 | eff(%):  5.227 | loglstar:   -inf < -81.976 <    inf | logz: -92.104 +/-  0.088 | dlogz: 34.323 >  1.009]/home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in exp
#   after removing the cwd from sys.path.
# /home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in multiply
#   after removing the cwd from sys.path.
# 8650it [03:43,  8.28it/s, bound: 88 | nc: 324 | ncall: 166256 | eff(%):  5.203 | loglstar:   -inf < -81.899 <    inf | logz: -92.081 +/-  0.088 | dlogz: 34.296 >  1.009]/home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in exp
#   after removing the cwd from sys.path.
# /home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in multiply
#   after removing the cwd from sys.path.
# 8654it [03:44,  5.26it/s, bound: 89 | nc: 55 | ncall: 167622 | eff(%):  5.163 | loglstar:   -inf < -81.881 <    inf | logz: -92.063 +/-  0.088 | dlogz: 34.273 >  1.009] /home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in exp
#   after removing the cwd from sys.path.
# /home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in multiply
#   after removing the cwd from sys.path.
# 8669it [03:47,  6.98it/s, bound: 91 | nc: 95 | ncall: 169959 | eff(%):  5.101 | loglstar:   -inf < -81.732 <    inf | logz: -91.991 +/-  0.089 | dlogz: 34.187 >  1.009] /home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in exp
#   after removing the cwd from sys.path.
# /home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in multiply
#   after removing the cwd from sys.path.
# 8756it [03:48, 51.04it/s, bound: 91 | nc: 2 | ncall: 171362 | eff(%):  5.110 | loglstar:   -inf < -80.973 <    inf | logz: -91.498 +/-  0.092 | dlogz: 33.608 >  1.009] /home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in exp
#   after removing the cwd from sys.path.
# 8768it [03:49, 23.46it/s, bound: 92 | nc: 6 | ncall: 171572 | eff(%):  5.110 | loglstar:   -inf < -80.857 <    inf | logz: -91.426 +/-  0.093 | dlogz: 33.524 >  1.009]/home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in multiply
#   after removing the cwd from sys.path.
# 8898it [03:50, 60.95it/s, bound: 93 | nc: 12 | ncall: 173170 | eff(%):  5.138 | loglstar:   -inf < -79.554 <    inf | logz: -90.521 +/-  0.096 | dlogz: 32.490 >  1.009]/home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in exp
#   after removing the cwd from sys.path.
# 8919it [03:50, 77.36it/s, bound: 93 | nc: 2 | ncall: 173329 | eff(%):  5.146 | loglstar:   -inf < -79.312 <    inf | logz: -90.349 +/-  0.097 | dlogz: 32.298 >  1.009] /home/federica/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in multiply
#   after removing the cwd from sys.path.
# 14733it [04:33, 53.85it/s, +1000 | bound: 119 | nc: 1 | ncall: 214024 | eff(%):  7.386 | loglstar:   -inf < -48.757 <    inf | logz: -63.383 +/-  0.123 | dlogz:  0.001 >  1.009]

# %%
# Plot a summary of the run.
rfig, raxes = dyplot.runplot(sresults)

# %%
label_brust = ['b', 'A', 't_0', 'alpha']

tfig, taxes = dyplot.traceplot(sresults, labels=label_brust)

# %%
#We make a corner plot
cfig, caxes = dyplot.cornerplot(sresults, labels=label_brust)

# %%
#We want to see if the results we obtained are equivalent to the ones we found with MCMC

#extract the samples and find the weights
samples = sresults.samples  # samples
weights = np.exp(sresults.logwt - sresults.logz[-1])  # normalized weights
evidence = sresults.logz[-1] #evidence
print("Bayesian evidence", np.exp(evidence))

# Compute 10%-90% quantiles
quantiles = [dyfunc.quantile(samps, [0.16, 0.84], weights=weights) for samps in samples.T]
print('68% parameter credible regions are:\n ' + str(quantiles) + '\n')
# Out:
# Bayesian evidence 2.9723894445647247e-28
# 68% parameter credible regions are:
#  [[10.171613306267924, 10.41909367362965], [4.1503252455919295, 7.207925392159294], [47.485414345662306, 51.1184509868824], [0.09888077051197369, 0.15094734647658103]]

# %%
# Resample weighted samples
samples_equal = dyfunc.resample_equal(samples, weights)

#make a new cornerplot
corner.corner(samples_equal, labels=label_brust, levels=[0.68,0.95], quantiles=[0.16, 0.84], show_titles=True);

# %% [markdown]
# We can see that the results we obtained are pretty equivalent to what we obtained for the MCMC.

# %%
median = np.empty(ndim)
quantile_95 = np.empty(ndim) 
quantile_05 = np.empty(ndim) 

for i in range(ndim):
    median[i] = np.median(samples_equal[:, i])
    quantile_95[i] = np.quantile(samples_equal[:, i], 0.95)
    quantile_05[i] = np.quantile(samples_equal[:, i], 0.05)
    
    up = quantile_95[i] - median[i]
    low = median[i] - quantile_05[i]
    
    print(label_brust[i],'=', str(round(median[i], 2)),'+', str(round(up, 2)), '-', str(round(low, 2)))
# Out:
# b = 10.3 + 0.2 - 0.2
# A = 5.38 + 3.48 - 1.8
# t_0 = 49.07 + 2.76 - 2.02
# alpha = 0.12 + 0.05 - 0.04

# %% [markdown]
# ## Gaussian Profile
#
# 8) Another possible model that may explain the data is a Gaussian profile described by:
#
# $y = b + A\exp[-(t-t_0)^2 / 2\sigma_W^2]$
#
# Fit this model usign nested sampling and reasonable priors (this time is up to you to decide...)

# %%
def gauss_model(p, t):
    b, A, t_0, sigma = p
    return b + A * np.exp(-(t-t_0)**2/(2*sigma**2))

# %% [markdown]
# We started by fitting manually the model to the data.

# %%
b = 10
A = 5
t_0 = 55 
sigma = 3

p = [b, A, t_0, sigma]

gauss_fit = gauss_model(p, t)

plt.plot(t, gauss_fit, label='Initial Model', color='r')
plt.errorbar(t, f, yerr=f_err, fmt='o', color='b', label='Data')
plt.xlabel('Time')
plt.ylabel('Flux')
plt.legend()
plt.title('Data with initial model')
plt.show()

# %%
#define the dimensionality of the problem
ndim = 4

#x are the samples
def priormodel(x): 
    b = x[0]*50
    A = x[1]*50
    t_0 = x[2]*100
    sigma = scipy.stats.loguniform.ppf(x[3], np.exp(-2), np.exp(2))
    
    param = np.array([b, A, t_0, sigma])
    return param


def loglike_model(param, t, f, f_err):
    b, A, t_0, sigma = param 
    model_brust_gauss = gauss_model(param, t)
    return (-0.5)* np.sum((f - model_brust_gauss)**2/(f_err**2))

# %%
#nested sampling

sampler_gauss = dynesty.NestedSampler(loglike_model, priormodel, ndim, logl_args=[t, f, f_err], nlive=1000)
sampler_gauss.run_nested()
sresults_gauss = sampler_gauss.results
# Out:
# 15387it [03:41, 69.48it/s, +1000 | bound: 101 | nc: 1 | ncall: 188628 | eff(%):  8.734 | loglstar:   -inf < -52.428 <    inf | logz: -67.809 +/-  0.132 | dlogz:  0.001 >  1.009]

# %%
# Plot a summary of the run.
rfig, raxes = dyplot.runplot(sresults_gauss)

# %%
label_brust_gauss = ['b', 'A', 't_0', 'sigma']

tfig, taxes = dyplot.traceplot(sresults_gauss, labels=label_brust_gauss)

# %%
#We want to see if the results we obtained are equivalent to the ones we found with MCMC

#extract the samples and find the weights
samples_gauss = sresults_gauss.samples  # samples
weights_gauss = np.exp(sresults_gauss.logwt - sresults_gauss.logz[-1])  # normalized weights
evidence_gauss = sresults_gauss.logz[-1] #evidence
print("Bayesian evidence", np.exp(evidence_gauss))

# Compute 10%-90% quantiles
quantiles_gauss = [dyfunc.quantile(samps, [0.16, 0.84], weights=weights_gauss) for samps in samples_gauss.T]
print('68% parameter credible regions are:\n ' + str(quantiles_gauss) + '\n')
# Out:
# Bayesian evidence 3.554318516509124e-30
# 68% parameter credible regions are:
#  [[10.2018414983733, 10.438308666217347], [2.398245345263625, 3.1424505051722087], [54.4098219883842, 56.36871468818613], [4.451399792473456, 6.050704316675853]]

# %%
# Resample weighted samples
samples_equal_gauss = dyfunc.resample_equal(samples_gauss, weights_gauss)

#make a new cornerplot
corner.corner(samples_equal_gauss, labels=label_brust_gauss, 
              levels=[0.68,0.95], quantiles=[0.16, 0.84], show_titles=True);

# %%
median_gauss = np.empty(ndim)
quantile_95 = np.empty(ndim) 
quantile_05 = np.empty(ndim) 

for i in range(ndim):
    median_gauss[i] = np.median(samples_equal_gauss[:, i])
    quantile_95[i] = np.quantile(samples_equal_gauss[:, i], 0.95)
    quantile_05[i] = np.quantile(samples_equal_gauss[:, i], 0.05)
    
    up = quantile_95[i] - median[i]
    low = median[i] - quantile_05[i]
    
    print(label_brust_gauss[i],'=', str(round(median_gauss[i], 2)),'+', 
          str(round(up, 2)), '-', str(round(low, 2)))
# Out:
# b = 10.32 + 0.22 - 0.17
# A = 2.75 + -1.99 - 3.23
# t_0 = 55.37 + 7.97 - -4.73
# sigma = 5.23 + 6.48 - -3.81

# %% [markdown]
# ## Model Comparison
#
# 9) Unlike MCMCs, nested sampling provides the Bayesian evidence. Compute the Bayesian evidence for this Gaussian model, and for the original burst model. Which model is the favored description of the data?

# %%
data_burst = samples_equal[np.random.choice(range(len(samples_equal)), 100)]
data_gauss = samples_equal_gauss[np.random.choice(range(len(samples_equal_gauss)), 100)]
time = np.linspace(0, 100, 100)

flux_burst = np.array([model(p, time) for p in data_burst])
flux_gauss = np.array([gauss_model(p, time) for p in data_gauss])

fig = plt.figure(figsize=(15,5))

ax = fig.add_subplot(121)

for i in range(len(flux_burst)):
    plt.plot(flux_burst[i], alpha=0.3, color='b', lw=1.2)
    plt.title('Postirior of Brurst Model')
    plt.xlabel('Time')
    plt.ylabel('Flux')

plt.errorbar(t, f, yerr=f_err, fmt='o', color='black', alpha=0.5, label='Data')

ax = fig.add_subplot(122)

for i in range(len(flux_gauss)):
    plt.plot(flux_gauss[i], alpha=0.3, color='b', lw=1.2)
    plt.title('Postirior of Gauss Model')
    plt.xlabel('Time')
    plt.ylabel('Flux')

plt.errorbar(t, f, yerr=f_err, fmt='o', color='black', alpha=0.5, label='Data')

plt.show()

# %%
#Find the Bayes factor

bayes_burst = np.exp(sresults.logz[-1])
bayes_gauss = np.exp(sresults_gauss.logz[-1])

bayes_factor = bayes_burst/bayes_gauss

print('The Bayes factor is:', bayes_factor)
# Out:
# The Bayes factor is: 83.62754859359254

# %% [markdown]
# We can evince from the Bayes factor that the Burst Model better describe the data that we are observing.
